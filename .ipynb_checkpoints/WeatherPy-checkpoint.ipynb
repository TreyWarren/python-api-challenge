# %% [markdown]
# # WeatherPy
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"In total we selected {len(cities)} cities.")
# Out:
# In total we selected 648 cities.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather"
units = 'imperial'
url_units = url + "?appid=" + weather_api_key + "&units=" + units

def cityQuery(city):
    return f"{url_units}&q={city}"

# %%
# set up lists to hold reponse info
temps = []
count = 0
set_count = 1
# Loop through the list of cities and perform a request for data on each
print('Beginning Data Retrieval')
print('-'*50)
for city in cities:
    count += 1
    if count%51 == 0:
        time.sleep(3)
        set_count += 1
        count = 1
    response = requests.get(cityQuery(city)).json()
    try:
        print(f"Processing Record {count} of Set {set_count} | {city}")
        temps.append({'City':response['name'],
                      'Cloudiness':response['clouds']['all'],
                      'Country':response['sys']['country'],
                      'Date':response['dt'],
                      'Humidity':response['main']['humidity'],
                      'Lat':response['coord']['lat'],
                      'Lng':response['coord']['lon'],
                      'Max Temp':response['main']['temp_max'],
                      'Wind Speed':response['wind']['speed']})
    except Exception as e:
        if e.args[0] == 'name':
            print('City not found. Skipping...')
        else:
            print(f"Didn't have any {e} listed.")
            
print('-'*50)
print('Data Retrieval Complete')
print('-'*50)
# Out:
# Beginning Data Retrieval
# --------------------------------------------------
# Processing Record 1 of Set 1 | saleilua
# City not found. Skipping...
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | eureka
# Processing Record 4 of Set 1 | bathsheba
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | haflong
# Processing Record 8 of Set 1 | shushtar
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | makakilo city
# Processing Record 11 of Set 1 | hamilton
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | saint-joseph
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | kawalu
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | sheltozero
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | jutai
# Processing Record 28 of Set 1 | temirtau
# Processing Record 29 of Set 1 | namibe
# Processing Record 30 of Set 1 | ode
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | huarmey
# Processing Record 33 of Set 1 | fortuna
# Processing Record 34 of Set 1 | whyalla
# Processing Record 35 of Set 1 | san pedro de cajas
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | seminole
# Processing Record 38 of Set 1 | saint-georges
# Processing Record 39 of Set 1 | mnogovershinnyy
# Processing Record 40 of Set 1 | fallon
# Processing Record 41 of Set 1 | touros
# Processing Record 42 of Set 1 | kirakira
# Processing Record 43 of Set 1 | bodden town
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | zhuhai
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | vardo
# Processing Record 7 of Set 2 | tyukhtet
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | palencia
# Processing Record 10 of Set 2 | katsuura
# Processing Record 11 of Set 2 | tura
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | carutapera
# Processing Record 16 of Set 2 | rybinsk
# Processing Record 17 of Set 2 | tayu
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | puerto del rosario
# Processing Record 21 of Set 2 | rikitea
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | labuhan
# Processing Record 24 of Set 2 | hutang
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | luau
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | alice springs
# Processing Record 30 of Set 2 | kutum
# Processing Record 31 of Set 2 | senekal
# Processing Record 32 of Set 2 | nakusp
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | ossora
# Processing Record 35 of Set 2 | pedernales
# Processing Record 36 of Set 2 | mount gambier
# Processing Record 37 of Set 2 | faya
# Processing Record 38 of Set 2 | yumen
# Processing Record 39 of Set 2 | plettenberg bay
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | lata
# Processing Record 43 of Set 2 | matara
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | aksu
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | kavieng
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | tilichiki
# Processing Record 1 of Set 3 | sumen
# City not found. Skipping...
# Processing Record 2 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 3 | marshfield
# Processing Record 4 of Set 3 | kurtamysh
# Processing Record 5 of Set 3 | athabasca
# Processing Record 6 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | teotitlan
# Processing Record 9 of Set 3 | orlik
# Processing Record 10 of Set 3 | umm kaddadah
# Processing Record 11 of Set 3 | ust-ilimsk
# Processing Record 12 of Set 3 | eluru
# Processing Record 13 of Set 3 | rocha
# Processing Record 14 of Set 3 | bideford
# Processing Record 15 of Set 3 | fort nelson
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | limbazi
# Processing Record 19 of Set 3 | ambilobe
# Processing Record 20 of Set 3 | bemidji
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | banda aceh
# Processing Record 24 of Set 3 | cabo san lucas
# Processing Record 25 of Set 3 | kenai
# Processing Record 26 of Set 3 | celestun
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 3 | quelimane
# Processing Record 30 of Set 3 | karasjok
# Processing Record 31 of Set 3 | mackay
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | cidreira
# Processing Record 34 of Set 3 | husavik
# Processing Record 35 of Set 3 | phan thiet
# Processing Record 36 of Set 3 | daru
# Processing Record 37 of Set 3 | zheleznodorozhnyy
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | joshimath
# Processing Record 40 of Set 3 | hithadhoo
# Processing Record 41 of Set 3 | puerto madryn
# Processing Record 42 of Set 3 | lerwick
# Processing Record 43 of Set 3 | neryungri
# Processing Record 44 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 3 | campana
# Processing Record 46 of Set 3 | poya
# Processing Record 47 of Set 3 | valparaiso
# Processing Record 48 of Set 3 | pryozerne
# Processing Record 49 of Set 3 | alice
# Processing Record 50 of Set 3 | jiayuguan
# Processing Record 1 of Set 4 | sisimiut
# Processing Record 2 of Set 4 | westport
# Processing Record 3 of Set 4 | puri
# Processing Record 4 of Set 4 | dhidhdhoo
# Processing Record 5 of Set 4 | ahlat
# Processing Record 6 of Set 4 | odweyne
# Processing Record 7 of Set 4 | san luis
# Processing Record 8 of Set 4 | los llanos de aridane
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | hattiesburg
# Processing Record 11 of Set 4 | saint-augustin
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | zhangjiakou
# Processing Record 16 of Set 4 | clonakilty
# Processing Record 17 of Set 4 | vanavara
# Processing Record 18 of Set 4 | saint-pierre
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | mataura
# Processing Record 21 of Set 4 | havelock
# Processing Record 22 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | singaraja
# Processing Record 25 of Set 4 | minsk
# Processing Record 26 of Set 4 | isla mujeres
# Processing Record 27 of Set 4 | suna
# Processing Record 28 of Set 4 | tevriz
# Processing Record 29 of Set 4 | loandjili
# Processing Record 30 of Set 4 | krasnoselkup
# Processing Record 31 of Set 4 | demba
# Processing Record 32 of Set 4 | laguna
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | saiha
# Processing Record 36 of Set 4 | harper
# Processing Record 37 of Set 4 | shingu
# Processing Record 38 of Set 4 | mollendo
# Processing Record 39 of Set 4 | saldanha
# Processing Record 40 of Set 4 | ixcaquixtla
# City not found. Skipping...
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | teya
# Processing Record 43 of Set 4 | santa cruz
# Processing Record 44 of Set 4 | newport
# Processing Record 45 of Set 4 | lazaro cardenas
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | bluff
# Processing Record 48 of Set 4 | barmer
# Processing Record 49 of Set 4 | ribeira grande
# Processing Record 50 of Set 4 | champasak
# Processing Record 1 of Set 5 | avarua
# Processing Record 2 of Set 5 | qaanaaq
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | siddapur
# Processing Record 5 of Set 5 | lincoln
# Processing Record 6 of Set 5 | pyshchug
# Processing Record 7 of Set 5 | prince george
# Processing Record 8 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 5 | ostrovnoy
# Processing Record 10 of Set 5 | verkhnevilyuysk
# Processing Record 11 of Set 5 | gurupi
# Processing Record 12 of Set 5 | ginda
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | omboue
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | popondetta
# Processing Record 17 of Set 5 | maniitsoq
# Processing Record 18 of Set 5 | bredasdorp
# Processing Record 19 of Set 5 | tarakan
# Processing Record 20 of Set 5 | santa maria
# Processing Record 21 of Set 5 | salalah
# Processing Record 22 of Set 5 | hecun
# Processing Record 23 of Set 5 | nanortalik
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 5 | colac
# Processing Record 26 of Set 5 | monroe
# Processing Record 27 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 5 | zarubino
# Processing Record 29 of Set 5 | falam
# Processing Record 30 of Set 5 | zarichne
# Processing Record 31 of Set 5 | chapais
# Processing Record 32 of Set 5 | storforshei
# Processing Record 33 of Set 5 | hilo
# Processing Record 34 of Set 5 | necochea
# Processing Record 35 of Set 5 | souillac
# Processing Record 36 of Set 5 | ust-maya
# Processing Record 37 of Set 5 | bonavista
# Processing Record 38 of Set 5 | biltine
# Processing Record 39 of Set 5 | leningradskiy
# Processing Record 40 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 5 | jimeta
# Processing Record 42 of Set 5 | bethel
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | caravelas
# Processing Record 45 of Set 5 | montlucon
# Processing Record 46 of Set 5 | simao
# Processing Record 47 of Set 5 | yamada
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | saryagash
# Processing Record 50 of Set 5 | nikolskoye
# Processing Record 1 of Set 6 | dunedin
# Processing Record 2 of Set 6 | lisakovsk
# Processing Record 3 of Set 6 | meulaboh
# Processing Record 4 of Set 6 | goycay
# City not found. Skipping...
# Processing Record 5 of Set 6 | aldan
# Processing Record 6 of Set 6 | ancud
# Processing Record 7 of Set 6 | aljezur
# Processing Record 8 of Set 6 | krasnozerskoye
# Processing Record 9 of Set 6 | jatai
# Processing Record 10 of Set 6 | lima
# Processing Record 11 of Set 6 | yingcheng
# Processing Record 12 of Set 6 | pacific grove
# Processing Record 13 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 6 | kaka
# Processing Record 15 of Set 6 | udachnyy
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | pangnirtung
# Processing Record 18 of Set 6 | gazojak
# Processing Record 19 of Set 6 | poykovskiy
# Processing Record 20 of Set 6 | asfi
# Processing Record 21 of Set 6 | thayetmyo
# Processing Record 22 of Set 6 | miri
# Processing Record 23 of Set 6 | zainsk
# Processing Record 24 of Set 6 | daloa
# Processing Record 25 of Set 6 | kalangala
# Processing Record 26 of Set 6 | dubbo
# Processing Record 27 of Set 6 | atbasar
# Processing Record 28 of Set 6 | villazon
# Processing Record 29 of Set 6 | yar-sale
# Processing Record 30 of Set 6 | karpuninskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | nishihara
# Processing Record 34 of Set 6 | samarai
# Processing Record 35 of Set 6 | tessalit
# Processing Record 36 of Set 6 | georgetown
# Processing Record 37 of Set 6 | mecca
# Processing Record 38 of Set 6 | anaco
# Processing Record 39 of Set 6 | la ronge
# Processing Record 40 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 42 of Set 6 | brigantine
# Processing Record 43 of Set 6 | plouzane
# Processing Record 44 of Set 6 | san cristobal
# Processing Record 45 of Set 6 | alyangula
# Processing Record 46 of Set 6 | rock springs
# Processing Record 47 of Set 6 | krasnogvardeyskiy
# Processing Record 48 of Set 6 | amapa
# Processing Record 49 of Set 6 | mossendjo
# Processing Record 50 of Set 6 | bandarbeyla
# Processing Record 1 of Set 7 | kushmurun
# Processing Record 2 of Set 7 | springfield
# Processing Record 3 of Set 7 | danjiangkou
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | ciudad bolivar
# Processing Record 6 of Set 7 | milford
# Processing Record 7 of Set 7 | roald
# Processing Record 8 of Set 7 | adrar
# Processing Record 9 of Set 7 | sao filipe
# Processing Record 10 of Set 7 | ambon
# Processing Record 11 of Set 7 | yenagoa
# Processing Record 12 of Set 7 | chenzhou
# Processing Record 13 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 7 | pisco
# Processing Record 15 of Set 7 | havoysund
# Processing Record 16 of Set 7 | south lake tahoe
# Processing Record 17 of Set 7 | pyinmana
# Processing Record 18 of Set 7 | vieste
# Processing Record 19 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 7 | batagay
# Processing Record 21 of Set 7 | lagoa
# Processing Record 22 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 7 | san quintin
# Processing Record 24 of Set 7 | brae
# Processing Record 25 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 7 | la serena
# Processing Record 27 of Set 7 | kishtwar
# Processing Record 28 of Set 7 | providencia
# Processing Record 29 of Set 7 | port hardy
# Processing Record 30 of Set 7 | tautira
# Processing Record 31 of Set 7 | ponta delgada
# Processing Record 32 of Set 7 | iskateley
# Processing Record 33 of Set 7 | vostok
# Processing Record 34 of Set 7 | sorkjosen
# Processing Record 35 of Set 7 | nome
# Processing Record 36 of Set 7 | bismarck
# Processing Record 37 of Set 7 | vila
# Processing Record 38 of Set 7 | hambantota
# Processing Record 39 of Set 7 | svetlyy
# Processing Record 40 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 7 | canutama
# Processing Record 42 of Set 7 | shimoda
# Processing Record 43 of Set 7 | linkuva
# Processing Record 44 of Set 7 | batagay-alyta
# Processing Record 45 of Set 7 | skelleftea
# Processing Record 46 of Set 7 | topolobampo
# Processing Record 47 of Set 7 | staryy nadym
# Processing Record 48 of Set 7 | turinsk
# Processing Record 49 of Set 7 | yaounde
# Processing Record 50 of Set 7 | arcachon
# Processing Record 1 of Set 8 | moose factory
# Processing Record 2 of Set 8 | anadyr
# Processing Record 3 of Set 8 | saint anthony
# Processing Record 4 of Set 8 | lebu
# Processing Record 5 of Set 8 | muros
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | saint-philippe
# Processing Record 8 of Set 8 | kupang
# Processing Record 9 of Set 8 | sechura
# Processing Record 10 of Set 8 | darnah
# Processing Record 11 of Set 8 | shagonar
# Processing Record 12 of Set 8 | besancon
# Processing Record 13 of Set 8 | churapcha
# Processing Record 14 of Set 8 | doctor arroyo
# Processing Record 15 of Set 8 | springbok
# Processing Record 16 of Set 8 | tsimlyansk
# Processing Record 17 of Set 8 | esna
# Processing Record 18 of Set 8 | puqi
# Processing Record 19 of Set 8 | grand gaube
# Processing Record 20 of Set 8 | grindavik
# Processing Record 21 of Set 8 | dunnville
# Processing Record 22 of Set 8 | zhifang
# Processing Record 23 of Set 8 | sept-iles
# Processing Record 24 of Set 8 | alugan
# Processing Record 25 of Set 8 | novoagansk
# Processing Record 26 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 8 | paamiut
# Processing Record 28 of Set 8 | honiara
# Processing Record 29 of Set 8 | lompoc
# Processing Record 30 of Set 8 | rawson
# Processing Record 31 of Set 8 | burnie
# Processing Record 32 of Set 8 | nezhinka
# Processing Record 33 of Set 8 | oistins
# Processing Record 34 of Set 8 | burica
# City not found. Skipping...
# Processing Record 35 of Set 8 | porto novo
# Processing Record 36 of Set 8 | waw
# Processing Record 37 of Set 8 | el vigia
# Processing Record 38 of Set 8 | rumuruti
# Processing Record 39 of Set 8 | antofagasta
# Processing Record 40 of Set 8 | bonfim
# Processing Record 41 of Set 8 | monrovia
# Processing Record 42 of Set 8 | kristiinankaupunki
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | the valley
# Processing Record 45 of Set 8 | tuy hoa
# Processing Record 46 of Set 8 | washington
# Processing Record 47 of Set 8 | gazanjyk
# Processing Record 48 of Set 8 | cap malheureux
# Processing Record 49 of Set 8 | wilmington
# Processing Record 50 of Set 8 | bontang
# Processing Record 1 of Set 9 | pousat
# City not found. Skipping...
# Processing Record 2 of Set 9 | surt
# Processing Record 3 of Set 9 | kahului
# Processing Record 4 of Set 9 | constitucion
# Processing Record 5 of Set 9 | agadez
# Processing Record 6 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 7 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 9 | gat
# Processing Record 9 of Set 9 | atambua
# Processing Record 10 of Set 9 | cabedelo
# Processing Record 11 of Set 9 | lasa
# Processing Record 12 of Set 9 | broome
# Processing Record 13 of Set 9 | petropavlovka
# Processing Record 14 of Set 9 | moyeuvre-grande
# Processing Record 15 of Set 9 | calama
# Processing Record 16 of Set 9 | hervey bay
# Processing Record 17 of Set 9 | klaksvik
# Processing Record 18 of Set 9 | diffa
# Processing Record 19 of Set 9 | novyy urgal
# Processing Record 20 of Set 9 | baraki barak
# Processing Record 21 of Set 9 | taoudenni
# Processing Record 22 of Set 9 | yuzhou
# Processing Record 23 of Set 9 | biggar
# Processing Record 24 of Set 9 | nalut
# Processing Record 25 of Set 9 | bakchar
# Processing Record 26 of Set 9 | gubkinskiy
# Processing Record 27 of Set 9 | north bend
# Processing Record 28 of Set 9 | tiznit
# Processing Record 29 of Set 9 | guozhen
# Processing Record 30 of Set 9 | cam ranh
# Processing Record 31 of Set 9 | kahta
# Processing Record 32 of Set 9 | batticaloa
# Processing Record 33 of Set 9 | mao
# Processing Record 34 of Set 9 | mitsamiouli
# Processing Record 35 of Set 9 | itanhaem
# Processing Record 36 of Set 9 | padang
# Processing Record 37 of Set 9 | tiarei
# Processing Record 38 of Set 9 | naze
# Processing Record 39 of Set 9 | sakakah
# Processing Record 40 of Set 9 | mitchell
# Processing Record 41 of Set 9 | beberibe
# Processing Record 42 of Set 9 | dillon
# Processing Record 43 of Set 9 | kangundo
# Processing Record 44 of Set 9 | bac lieu
# Processing Record 45 of Set 9 | afyonkarahisar
# Processing Record 46 of Set 9 | ruteng
# Processing Record 47 of Set 9 | quang ngai
# Processing Record 48 of Set 9 | talnakh
# Processing Record 49 of Set 9 | umm lajj
# Processing Record 50 of Set 9 | korogwe
# City not found. Skipping...
# Processing Record 1 of Set 10 | sokolo
# Processing Record 2 of Set 10 | abalak
# Processing Record 3 of Set 10 | urumqi
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | amalapuram
# Processing Record 6 of Set 10 | abu dhabi
# Processing Record 7 of Set 10 | timmins
# Processing Record 8 of Set 10 | ahipara
# Processing Record 9 of Set 10 | gamba
# Processing Record 10 of Set 10 | half moon bay
# Processing Record 11 of Set 10 | acapulco
# Processing Record 12 of Set 10 | baculin
# Processing Record 13 of Set 10 | balabac
# Processing Record 14 of Set 10 | zhigalovo
# Processing Record 15 of Set 10 | leon
# Processing Record 16 of Set 10 | ulaanbaatar
# Processing Record 17 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 10 | north myrtle beach
# Processing Record 19 of Set 10 | whitehorse
# Processing Record 20 of Set 10 | boa vista
# Processing Record 21 of Set 10 | riyadh
# Processing Record 22 of Set 10 | wuwei
# Processing Record 23 of Set 10 | gravdal
# Processing Record 24 of Set 10 | wawina
# Processing Record 25 of Set 10 | biak
# Processing Record 26 of Set 10 | inta
# Processing Record 27 of Set 10 | stephenville
# Processing Record 28 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 10 | kidal
# Processing Record 30 of Set 10 | kangaatsiaq
# Processing Record 31 of Set 10 | baraut
# Processing Record 32 of Set 10 | la romana
# Processing Record 33 of Set 10 | tres picos
# Processing Record 34 of Set 10 | lakselv
# Processing Record 35 of Set 10 | itarema
# Processing Record 36 of Set 10 | gzhatsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | dandong
# Processing Record 38 of Set 10 | amla
# Processing Record 39 of Set 10 | ilo
# Processing Record 40 of Set 10 | santiago
# Processing Record 41 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 10 | kenora
# Processing Record 43 of Set 10 | saint george
# Processing Record 44 of Set 10 | oriximina
# Processing Record 45 of Set 10 | ridgecrest
# Processing Record 46 of Set 10 | kroonstad
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | black river
# Processing Record 49 of Set 10 | lakes entrance
# Processing Record 50 of Set 10 | palauig
# Processing Record 1 of Set 11 | najran
# Processing Record 2 of Set 11 | elko
# Processing Record 3 of Set 11 | tambura
# Processing Record 4 of Set 11 | lavrentiya
# Processing Record 5 of Set 11 | ruthin
# Processing Record 6 of Set 11 | oskaloosa
# Processing Record 7 of Set 11 | shenjiamen
# Processing Record 8 of Set 11 | ormara
# Processing Record 9 of Set 11 | novokayakent
# Processing Record 10 of Set 11 | rabo de peixe
# Processing Record 11 of Set 11 | svetlaya
# Processing Record 12 of Set 11 | jumla
# Processing Record 13 of Set 11 | tezu
# Processing Record 14 of Set 11 | dingle
# Processing Record 15 of Set 11 | chumikan
# Processing Record 16 of Set 11 | sobradinho
# Processing Record 17 of Set 11 | berlevag
# Processing Record 18 of Set 11 | port arthur
# Processing Record 19 of Set 11 | beyneu
# Processing Record 20 of Set 11 | pasighat
# Processing Record 21 of Set 11 | wucheng
# Processing Record 22 of Set 11 | okha
# Processing Record 23 of Set 11 | vidalia
# Processing Record 24 of Set 11 | acari
# Processing Record 25 of Set 11 | rorvik
# Processing Record 26 of Set 11 | mezen
# Processing Record 27 of Set 11 | christchurch
# Processing Record 28 of Set 11 | guerrero negro
# Processing Record 29 of Set 11 | hillsborough
# Processing Record 30 of Set 11 | waingapu
# Processing Record 31 of Set 11 | college
# Processing Record 32 of Set 11 | conceicao do mato dentro
# Processing Record 33 of Set 11 | hami
# Processing Record 34 of Set 11 | port-cartier
# Processing Record 35 of Set 11 | verkhnyaya inta
# Processing Record 36 of Set 11 | takaka
# Processing Record 37 of Set 11 | nelson bay
# Processing Record 38 of Set 11 | bubaque
# Processing Record 39 of Set 11 | inongo
# Processing Record 40 of Set 11 | baherden
# Processing Record 41 of Set 11 | beloha
# Processing Record 42 of Set 11 | surskoye
# Processing Record 43 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 45 of Set 11 | dudinka
# Processing Record 46 of Set 11 | panaba
# Processing Record 47 of Set 11 | margate
# Processing Record 48 of Set 11 | usevya
# Processing Record 49 of Set 11 | bud
# Processing Record 50 of Set 11 | vestmannaeyjar
# Processing Record 1 of Set 12 | ames
# Processing Record 2 of Set 12 | ponta pora
# Processing Record 3 of Set 12 | coachella
# Processing Record 4 of Set 12 | ust-ishim
# Processing Record 5 of Set 12 | sanary-sur-mer
# Processing Record 6 of Set 12 | osoyoos
# Processing Record 7 of Set 12 | taltal
# Processing Record 8 of Set 12 | vao
# Processing Record 9 of Set 12 | nador
# Processing Record 10 of Set 12 | moyale
# Processing Record 11 of Set 12 | cayenne
# Processing Record 12 of Set 12 | lardos
# Processing Record 13 of Set 12 | malanje
# Processing Record 14 of Set 12 | kudahuvadhoo
# Processing Record 15 of Set 12 | balkanabat
# Processing Record 16 of Set 12 | kyren
# Processing Record 17 of Set 12 | lashio
# Processing Record 18 of Set 12 | normandin
# Processing Record 19 of Set 12 | basoko
# Processing Record 20 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 12 | juneau
# Processing Record 22 of Set 12 | makat
# Processing Record 23 of Set 12 | mangan
# Processing Record 24 of Set 12 | palu
# Processing Record 25 of Set 12 | wajima
# Processing Record 26 of Set 12 | estevan
# Processing Record 27 of Set 12 | salinopolis
# Processing Record 28 of Set 12 | abonnema
# Processing Record 29 of Set 12 | jieshi
# Processing Record 30 of Set 12 | floro
# Processing Record 31 of Set 12 | barcelos
# Processing Record 32 of Set 12 | mizdah
# Processing Record 33 of Set 12 | porbandar
# Processing Record 34 of Set 12 | barra do corda
# Processing Record 35 of Set 12 | suhbaatar
# Processing Record 36 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 12 | axim
# Processing Record 38 of Set 12 | mandalgovi
# Processing Record 39 of Set 12 | ajdabiya
# Processing Record 40 of Set 12 | shitkino
# Processing Record 41 of Set 12 | baglan
# Processing Record 42 of Set 12 | tabory
# Processing Record 43 of Set 12 | nha trang
# Processing Record 44 of Set 12 | rockingham
# Processing Record 45 of Set 12 | maneadero
# Processing Record 46 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 47 of Set 12 | qasigiannguit
# Processing Record 48 of Set 12 | manali
# Processing Record 49 of Set 12 | price
# Processing Record 50 of Set 12 | norden
# Processing Record 1 of Set 13 | zhigansk
# Processing Record 2 of Set 13 | asau
# Processing Record 3 of Set 13 | kadoma
# Processing Record 4 of Set 13 | matay
# Processing Record 5 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 13 | torres vedras
# Processing Record 8 of Set 13 | wanaka
# Processing Record 9 of Set 13 | yumaguzino
# Processing Record 10 of Set 13 | banswara
# Processing Record 11 of Set 13 | vaitape
# Processing Record 12 of Set 13 | chirkey
# Processing Record 13 of Set 13 | kuala krai
# City not found. Skipping...
# Processing Record 14 of Set 13 | aykhal
# Processing Record 15 of Set 13 | knysna
# Processing Record 16 of Set 13 | high river
# Processing Record 17 of Set 13 | prince rupert
# Processing Record 18 of Set 13 | manjacaze
# Processing Record 19 of Set 13 | ulfborg
# Processing Record 20 of Set 13 | veraval
# Processing Record 21 of Set 13 | baruun-urt
# Processing Record 22 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 23 of Set 13 | hobyo
# Processing Record 24 of Set 13 | goya
# Processing Record 25 of Set 13 | pozo colorado
# Processing Record 26 of Set 13 | olonets
# Processing Record 27 of Set 13 | rio gallegos
# Processing Record 28 of Set 13 | kruisfontein
# Processing Record 29 of Set 13 | giyani
# Processing Record 30 of Set 13 | gizo
# Processing Record 31 of Set 13 | corum
# Processing Record 32 of Set 13 | fairbanks
# Processing Record 33 of Set 13 | zhanakorgan
# Processing Record 34 of Set 13 | labytnangi
# Processing Record 35 of Set 13 | fountain hills
# Processing Record 36 of Set 13 | richards bay
# Processing Record 37 of Set 13 | sabha
# Processing Record 38 of Set 13 | smolenskoye
# Processing Record 39 of Set 13 | nerang
# Processing Record 40 of Set 13 | ayan
# Processing Record 41 of Set 13 | evensk
# Processing Record 42 of Set 13 | qui nhon
# Processing Record 43 of Set 13 | celadna
# Processing Record 44 of Set 13 | belyy yar
# Processing Record 45 of Set 13 | quatre cocos
# Processing Record 46 of Set 13 | nouadhibou
# Processing Record 47 of Set 13 | valleyview
# Processing Record 48 of Set 13 | ketchikan
# --------------------------------------------------
# Data Retrieval Complete
# --------------------------------------------------

# %%
print(f"There were {len(cities)-len(temps)} cities that the API couldn't find.")
print(f"So now we are left with data from {len(temps)} cities.")
# Out:
# There were 48 cities that the API couldn't find.
# So now we are left with data from 600 cities.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create the DataFrame
weather_df = pd.DataFrame(temps)
# Display the DataFrame
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Eureka          90      US  1585072007        87  40.80 -124.16
# 1  Bathsheba          40      BB  1585072007        62  13.22  -59.52
# 2      Tiksi          23      RU  1585072007        95  71.69  128.87
# 3   Hermanus           0      ZA  1585072007        69 -34.42   19.23
# 4    Hāflong           0      IN  1585072007        60  25.18   93.03
#
#    Max Temp  Wind Speed
# 0     51.01       10.29
# 1     84.20       21.92
# 2    -23.71        2.93
# 3     70.00        3.00
# 4     67.01        2.53

# %%
# Be sure that we have all the information (600) in each column
weather_df.count()
# Out:
# City          600
# Cloudiness    600
# Country       600
# Date          600
# Humidity      600
# Lat           600
# Lng           600
# Max Temp      600
# Wind Speed    600
# dtype: int64

# %%
# and output the data as a csv to our previously saved location
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# I'm going to defint a function that will plot each of our desired comparisons
def Lat_vs_plot(y_values, units):
    
    # Start by establishing the figure size
    plt.figure(figsize=(10, 7))
    
    # Every plot has the Lat as the x-axis, and for fun, I will make each plot
    #  also have Lng as the colored z-axis to see if we can find any other relationships
    plt.scatter(weather_df["Lat"], weather_df[y_values],
                edgecolors="black", alpha=0.7, c=weather_df['Lng'])
    
    # This will create a title with the date of which you run your data collection
    plt.title(f"City Latitude vs. {y_values} ({time.strftime('%m/%d/%y')})")
    
    # All of the other typical labels, limits, and saving the figure
    plt.xlabel("Latitude")
    plt.ylabel(f"{y_values} ({units})")
    plt.colorbar(label= 'Longitude')
    plt.xlim(-60,80)
    plt.grid (b=True, which="major", axis="both", color="lightgrey")
    plt.savefig(f"output_data/Lat_vs_{y_values}.png")
    plt.show()

# %%
Lat_vs_plot('Max Temp', 'F')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
Lat_vs_plot('Humidity', '%')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
Lat_vs_plot('Cloudiness', '%')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
Lat_vs_plot('Wind Speed', 'mph')

# %% [markdown]
# ## Linear Regression

# %%
# I'm going to again define a finction that will plot the Northern
#  and Southern regression lines on the respective scatter plots
def Northern_Lat_Regression(y, units):
    
    # Convert to floats and store Northern Latitudes and Max Temps as x and y values
    x_values = weather_df.loc[weather_df['Lat']>0]['Lat'].astype(float)
    y_values = weather_df.loc[weather_df['Lat']>0][y].astype(float)
    z_values = weather_df.loc[weather_df['Lat']>0]['Lng'].astype(float)
    
    # Run linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot scatter plot, regression line and the line equation 
    plt.scatter(x_values, y_values, c=z_values, alpha=0.5)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(0,y_values.mean()),fontsize=15,color="red")

    # Label plot
    plt.xlabel('Latitude')
    plt.ylabel(f"{y} ({units})")
    plt.colorbar(label= 'Longitude')

    #Save an image
    plt.savefig(f"output_data/North_Hem_{y}_Regression.png")

    # Print r square value
    print(f"R squard: {rvalue**2}")

    # Show plot
    plt.show()

# %%
# Same as above
def Southern_Lat_Regression(y, units):
    x_values = weather_df.loc[weather_df['Lat']<0]['Lat'].astype(float)
    y_values = weather_df.loc[weather_df['Lat']<0][y].astype(float)
    z_values = weather_df.loc[weather_df['Lat']<0]['Lng'].astype(float)
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values, y_values, c=z_values, alpha=0.5)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(-50,y_values.mean()),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f"{y} ({units})")
    plt.colorbar(label= 'Longitude')
    plt.savefig(f"output_data/South_Hem_{y}_Regression.png")
    print(f"R squard: {rvalue**2}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Northern_Lat_Regression('Max Temp', 'F')
# Out:
# R squard: 0.750913705871143

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Southern_Lat_Regression('Max Temp', 'F')
# Out:
# R squard: 0.34798685409734614

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Northern_Lat_Regression('Humidity', '%')
# Out:
# R squard: 0.0813666674879288

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Southern_Lat_Regression('Humidity', '%')
# Out:
# R squard: 0.054169597258506265

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Northern_Lat_Regression('Cloudiness', '%')
# Out:
# R squard: 0.09433143889647017

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Southern_Lat_Regression('Cloudiness', '%')
# Out:
# R squard: 0.029002362755998788

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Northern_Lat_Regression('Wind Speed', 'mph')
# Out:
# R squard: 0.025369328146006523

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Southern_Lat_Regression('Wind Speed', 'mph')
# Out:
# R squard: 0.05469528082265544

# %% [markdown]
# ## Analysis
# * Temperature increases as we approach the equator as expected. The Southern hemisphere was a bit more disperse than the Northern, this could be due to the time of year. Would be interesting to run this once a quarter.
#
#
# * Geographic location doesn't seem to have an effect on humidity, cloudiness, or wind speed. I assume topography and proximity to large bodies of water affect those much more.
#
#
# * Not much came from breaking out the Longitude in the colored z-axis except in one plot: notice on the Northern_Lat_Regression plot for Temperature that between -50 to -150 Longitude ( *North America* ) it seems to be slightly warmer compared to 50 to 150 Longitude ( *Asia* ). There is a chance this is due to my samples, but it showed up all three times I reran the random generator cell to get new cities. It is more likely that today it's just a bit warmer on this side of the world than that side. Hard to prove anything more conclusive than that unless I run it different times throughout the year...
